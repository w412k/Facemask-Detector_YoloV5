# %% [markdown]
# # Import Dependencies

# %%
import torch # YOLOv5 implemented using pytorch
from IPython.display import Image #this is to render predictions
import os

# %%
# %cd C:\Users\Mark Vincent\Desktop\mask
# Out:
# C:\Users\Mark Vincent\Desktop\mask

# %%
#!git clone https://github.com/ultralytics/yolov5

# %%
# %cd yolov5
# Out:
# C:\Users\Mark Vincent\Desktop\mask\yolov5

# %% [markdown]
# # Clone github YoloV5 repo

# %%
# !git clone https://github.com/ultralytics/yolov5

# %% [markdown]
# # Create .yaml file

# %%
# Define the desired folder path
folder_path = 'C:\\Users\Mark Vincent\Desktop\mask'

# Define the complete file path, including the desired folder and file name
file_path = os.path.join(folder_path, 'config.yaml')

# Create the YAML file for your dataset
data_yaml = f'''
train: C:\\Users\\Mark Vincent\\Desktop\\mask\\yolov5\\data\\custom_data\\images\\train
val: C:\\Users\\Mark Vincent\\Desktop\\mask\\yolov5\\data\\custom_data\\images\\val

nc: 1
names: ['mask']
'''

#train = training images path
#val = val images path

# Save the YAML file
with open('config.yaml', 'w') as file:
    file.write(data_yaml)

# %% [markdown]
# # Training

# %%
# !python train.py --img 415 --batch 1 --epochs 10 --data config.yaml --weights yolov5n.pt --cache disk
# Out:
# train: weights=yolov5n.pt, cfg=, data=config.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=10, batch_size=1, imgsz=415, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=disk, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\Mark': No such file or directory
# YOLOv5  2023-6-4 Python-3.8.16 torch-2.0.1+cpu CPU
#
# ...

# %% [markdown]
# # inference model (video)

# %%
# !python detect.py --weights runs\train\exp3\weights\last.pt --source data\masktest.mp4
# Out:
# detect: weights=['runs\\train\\exp3\\weights\\last.pt'], source=data\masktest.mp4, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Mark': No such file or directory
# YOLOv5  2023-6-4 Python-3.8.16 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# video 1/1 (1/523) C:\Users\Mark Vincent\Desktop\mask\yolov5\data\masktest.mp4: 384x640 6 masks, 106.3ms
# video 1/1 (2/523) C:\Users\Mark Vincent\Desktop\mask\yolov5\data\masktest.mp4: 384x640 6 masks, 93.5ms
# ...

# %%
# !python detect.py --weights runs\train\exp3\weights\last.pt --source data\facemask.jpg
# Out:
# detect: weights=['runs\\train\\exp3\\weights\\best.pt'], source=data\facemask.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to 'C:\Users\Mark': No such file or directory
# YOLOv5  2023-6-4 Python-3.8.16 torch-2.0.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# image 1/1 C:\Users\Mark Vincent\Desktop\mask\yolov5\data\facemask.jpg: 448x640 (no detections), 135.6ms
# Speed: 1.0ms pre-process, 135.6ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\exp8
